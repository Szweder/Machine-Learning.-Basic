# %% [markdown]
# # Homework 4 — “Git push -f” или после нас хоть потоп
# ---

# %%
#Задача 1 — Хлеб для хоббитов

def share_bread(N, K):
    """
    Делит K кусков хлеба на N хоббитов.
    Возвращает:
    - x: сколько кусков достанется каждому хоббиту
    - y: сколько останется в корзинке у Сэма
    """
    x = K // N
    y = K % N
    return x, y

# Проверка
assert share_bread(N=3, K=14) == (4, 2)

# %%
#Задача 2 — Високосный год

def leap_year(year):
    """
    Проверяет, является ли год високосным.
    Возвращает 'YOU SHALL PASS' если да, иначе 'YOU SHALL NOT PASS'
    """
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return 'YOU SHALL PASS'
    else:
        return 'YOU SHALL NOT PASS'

# Проверка
assert leap_year(5) == 'YOU SHALL NOT PASS'

# %%
#Задача 3 — Площадь амулета Гендальфа

def amulet_area(a, b, c):
    """
    Считает площадь треугольника по формуле Герона.
    """
    s = (a + b + c) / 2
    S = (s * (s - a) * (s - b) * (s - c)) ** 0.5
    return S

# Проверка
assert amulet_area(3, 4, 5) == 6

# %%
#Задача 4 — Метрики расстояний до Мордора

import numpy as np

def cal_euclidean(a, b):
    """
    Евклидово расстояние между двумя векторами
    """
    return sum((x - y) ** 2 for x, y in zip(a, b)) ** 0.5

def cal_manhattan(a, b):
    """
    Манхэттенское расстояние между двумя векторами
    """
    return sum(abs(x - y) for x, y in zip(a, b))

def cal_cosine(a, b):
    """
    Косинусное расстояние между двумя векторами
    """
    dot = sum(x * y for x, y in zip(a, b))
    norm_a = sum(x ** 2 for x in a) ** 0.5
    norm_b = sum(y ** 2 for y in b) ** 0.5
    return 1 - dot / (norm_a * norm_b)

# %%
# Пример работы с метриками
a = np.random.randint(-10, 10, size=10)
b = np.random.randint(-10, 10, size=10)

print("a =", a)
print("b =", b)
print("📐 Euclidean:", cal_euclidean(a, b))
print("🏙️ Manhattan:", cal_manhattan(a, b))
print("🧭 Cosine:", cal_cosine(a, b))
# Out:
# a = [ -7  -5  -8  -8 -10  -7  -6   7  -7  -7]
# b = [-1 -9 -5  3 -1  5 -9  6  1 -3]
# 📐 Euclidean: 22.293496809607955
# 🏙️ Manhattan: 61
# 🧭 Cosine: 0.5963130945097947
